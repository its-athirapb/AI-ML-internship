# %%
import pandas as pd

# %%
data={'Name':['Alice','Bob'],'Age':[25,30]}
df=pd.DataFrame(data)

# %%
lst=[['Alice',25],['Bob',30]]
df=pd.DataFrame(lst,columns=['Name','Age'])

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df[df['Age']>25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender']=['F','M']
df.drop('Gender',axis=1, inplace=True)

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False

# %%
df.dropna()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.fillna(0)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df['Age'] = [25, 30]
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.groupby('Name')['Age'].mean()
# Out:
# Name
# Alice    25.0
# Bob      30.0
# Name: Age, dtype: float64

# %%
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie']
})
df2 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Marks': [85, 90, 78]
})
pd.merge(df1, df2, on='ID')
# Out:
#    ID     Name  Marks
# 0   1    Alice     85
# 1   2      Bob     90
# 2   3  Charlie     78

# %%
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie']
})
df2 = pd.DataFrame({
    'Marks': [85, 90, 78]
})
df1.join(df2)
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\LENOVO\OneDrive\Desktop\aiml
# ['.ipynb_checkpoints', 'array.ipynb', 'array.npy', 'pandas.ipynb', 'Untitled.ipynb']

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob'],
    'Age': [25, 30]
}

df = pd.DataFrame(data)

df.to_csv('output.csv', index=False)

# %%
df = pd.read_csv('output.csv')
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.to_csv('output.csv',index=False)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.sort_values('Age')
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df['Age'].apply(lambda x: x+1)
# Out:
# 0    26
# 1    31
# Name: Age, dtype: int64

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob']
# Length: 2, dtype: str

# %%
df['Age'].value_counts()
# Out:
# Age
# 25    1
# 30    1
# Name: count, dtype: int64
